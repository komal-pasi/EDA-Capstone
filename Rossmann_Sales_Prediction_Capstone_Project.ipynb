# %% [markdown]
# <a href="https://colab.research.google.com/github/komal-pasi/EDA-Capstone/blob/main/Rossmann_Sales_Prediction_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <b><u> Project Title : Sales Prediction : Predicting sales of a major store chain Rossmann</u></b>

# %% [markdown]
# ## <b> Problem Description </b>
#
# ### Rossmann operates over 3,000 drug stores in 7 European countries. Currently, Rossmann store managers are tasked with predicting their daily sales for up to six weeks in advance. Store sales are influenced by many factors, including promotions, competition, school and state holidays, seasonality, and locality. With thousands of individual managers predicting sales based on their unique circumstances, the accuracy of results can be quite varied.
#
# ### You are provided with historical sales data for 1,115 Rossmann stores. The task is to forecast the "Sales" column for the test set. Note that some stores in the dataset were temporarily closed for refurbishment.

# %% [markdown]
# ## <b> Data Description </b>
#
# ### <b>Rossmann Stores Data.csv </b> - historical data including Sales
# ### <b>store.csv </b> - supplemental information about the stores
#
#
# ### <b><u>Data fields</u></b>
# ### Most of the fields are self-explanatory. The following are descriptions for those that aren't.
#
# * #### Id - an Id that represents a (Store, Date) duple within the test set
# * #### Store - a unique Id for each store
# * #### Sales - the turnover for any given day (this is what you are predicting)
# * #### Customers - the number of customers on a given day
# * #### Open - an indicator for whether the store was open: 0 = closed, 1 = open
# * #### StateHoliday - indicates a state holiday. Normally all stores, with few exceptions, are closed on state holidays. Note that all schools are closed on public holidays and weekends. a = public holiday, b = Easter holiday, c = Christmas, 0 = None
# * #### SchoolHoliday - indicates if the (Store, Date) was affected by the closure of public schools
# * #### StoreType - differentiates between 4 different store models: a, b, c, d
# * #### Assortment - describes an assortment level: a = basic, b = extra, c = extended
# * #### CompetitionDistance - distance in meters to the nearest competitor store
# * #### CompetitionOpenSince[Month/Year] - gives the approximate year and month of the time the nearest competitor was opened
# * #### Promo - indicates whether a store is running a promo on that day
# * #### Promo2 - Promo2 is a continuing and consecutive promotion for some stores: 0 = store is not participating, 1 = store is participating
# * #### Promo2Since[Year/Week] - describes the year and calendar week when the store started participating in Promo2
# * #### PromoInterval - describes the consecutive intervals Promo2 is started, naming the months the promotion is started anew. E.g. "Feb,May,Aug,Nov" means each round starts in February, May, August, November of any given year for that store

# %%
#Mount Google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Copy file location
File1 = "/content/drive/MyDrive/Capstone ML - 1/store.csv"
File2= "/content/drive/MyDrive/Capstone ML - 1/Rossmann Stores Data.csv"

# %%
store_data=pd.read_csv(File1)
rossman_store=pd.read_csv(File2)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
store_data.head()
# Out:
#    Store StoreType  ... Promo2SinceYear    PromoInterval
# 0      1         c  ...             NaN              NaN
# 1      2         a  ...          2010.0  Jan,Apr,Jul,Oct
# 2      3         a  ...          2011.0  Jan,Apr,Jul,Oct
# 3      4         c  ...             NaN              NaN
# 4      5         a  ...             NaN              NaN
#
# [5 rows x 10 columns]

# %%
store_data.tail()
# Out:
#       Store StoreType  ... Promo2SinceYear     PromoInterval
# 1110   1111         a  ...          2013.0   Jan,Apr,Jul,Oct
# 1111   1112         c  ...             NaN               NaN
# 1112   1113         a  ...             NaN               NaN
# 1113   1114         a  ...             NaN               NaN
# 1114   1115         d  ...          2012.0  Mar,Jun,Sept,Dec
#
# [5 rows x 10 columns]

# %%
store_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int64
#  1   StoreType                  1115 non-null   object
#  2   Assortment                 1115 non-null   object
#  3   CompetitionDistance        1112 non-null   float64
#  4   CompetitionOpenSinceMonth  761 non-null    float64
#  5   CompetitionOpenSinceYear   761 non-null    float64
#  6   Promo2                     1115 non-null   int64
#  7   Promo2SinceWeek            571 non-null    float64
#  8   Promo2SinceYear            571 non-null    float64
#  9   PromoInterval              571 non-null    object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB

# %%
store_data.hist(figsize=(20,20),color='#2E3192')
plt.show()

# %%
store_data[store_data.CompetitionDistance.isnull()]
# Out:
#      Store StoreType  ... Promo2SinceYear    PromoInterval
# 290    291         d  ...             NaN              NaN
# 621    622         a  ...             NaN              NaN
# 878    879         d  ...          2013.0  Feb,May,Aug,Nov
#
# [3 rows x 10 columns]

# %%
store_data.CompetitionDistance.fillna(store_data.CompetitionDistance.mean(),inplace=True)

# %%
store_data.head()
# Out:
#    Store StoreType  ... Promo2SinceYear    PromoInterval
# 0      1         c  ...             NaN              NaN
# 1      2         a  ...          2010.0  Jan,Apr,Jul,Oct
# 2      3         a  ...          2011.0  Jan,Apr,Jul,Oct
# 3      4         c  ...             NaN              NaN
# 4      5         a  ...             NaN              NaN
#
# [5 rows x 10 columns]

# %%
store_data[store_data.CompetitionOpenSinceMonth.isnull()]
# Out:
#       Store StoreType  ... Promo2SinceYear     PromoInterval
# 11       12         a  ...          2010.0   Jan,Apr,Jul,Oct
# 12       13         d  ...          2009.0   Feb,May,Aug,Nov
# 15       16         a  ...             NaN               NaN
# 18       19         a  ...          2011.0  Mar,Jun,Sept,Dec
# 21       22         a  ...          2012.0   Jan,Apr,Jul,Oct
# ...     ...       ...  ...             ...               ...
# 1095   1096         a  ...          2014.0  Mar,Jun,Sept,Dec
# 1099   1100         a  ...          2011.0   Jan,Apr,Jul,Oct
# 1112   1113         a  ...             NaN               NaN
# 1113   1114         a  ...             NaN               NaN
# 1114   1115         d  ...          2012.0  Mar,Jun,Sept,Dec
#
# [354 rows x 10 columns]

# %%
store_data.CompetitionOpenSinceMonth.fillna(0,inplace=True)
store_data.head()
# Out:
#    Store StoreType  ... Promo2SinceYear    PromoInterval
# 0      1         c  ...             NaN              NaN
# 1      2         a  ...          2010.0  Jan,Apr,Jul,Oct
# 2      3         a  ...          2011.0  Jan,Apr,Jul,Oct
# 3      4         c  ...             NaN              NaN
# 4      5         a  ...             NaN              NaN
#
# [5 rows x 10 columns]

# %%
store_data[store_data.Promo2SinceWeek.isnull()]
# Out:
#       Store StoreType  ... Promo2SinceYear  PromoInterval
# 0         1         c  ...             NaN            NaN
# 3         4         c  ...             NaN            NaN
# 4         5         a  ...             NaN            NaN
# 5         6         a  ...             NaN            NaN
# 6         7         a  ...             NaN            NaN
# ...     ...       ...  ...             ...            ...
# 1107   1108         a  ...             NaN            NaN
# 1109   1110         c  ...             NaN            NaN
# 1111   1112         c  ...             NaN            NaN
# 1112   1113         a  ...             NaN            NaN
# 1113   1114         a  ...             NaN            NaN
#
# [544 rows x 10 columns]

# %%
store_data.Promo2SinceWeek.fillna(0,inplace=True)
store_data.head()
# Out:
#    Store StoreType  ... Promo2SinceYear    PromoInterval
# 0      1         c  ...             NaN              NaN
# 1      2         a  ...          2010.0  Jan,Apr,Jul,Oct
# 2      3         a  ...          2011.0  Jan,Apr,Jul,Oct
# 3      4         c  ...             NaN              NaN
# 4      5         a  ...             NaN              NaN
#
# [5 rows x 10 columns]

# %%
store_data.Promo2SinceYear.fillna(0,inplace=True)
store_data.head()
# Out:
#    Store StoreType  ... Promo2SinceYear    PromoInterval
# 0      1         c  ...             0.0              NaN
# 1      2         a  ...          2010.0  Jan,Apr,Jul,Oct
# 2      3         a  ...          2011.0  Jan,Apr,Jul,Oct
# 3      4         c  ...             0.0              NaN
# 4      5         a  ...             0.0              NaN
#
# [5 rows x 10 columns]

# %%
store_data[store_data.CompetitionOpenSinceYear.isnull()]
# Out:
#       Store StoreType  ... Promo2SinceYear     PromoInterval
# 11       12         a  ...          2010.0   Jan,Apr,Jul,Oct
# 12       13         d  ...          2009.0   Feb,May,Aug,Nov
# 15       16         a  ...             0.0               NaN
# 18       19         a  ...          2011.0  Mar,Jun,Sept,Dec
# 21       22         a  ...          2012.0   Jan,Apr,Jul,Oct
# ...     ...       ...  ...             ...               ...
# 1095   1096         a  ...          2014.0  Mar,Jun,Sept,Dec
# 1099   1100         a  ...          2011.0   Jan,Apr,Jul,Oct
# 1112   1113         a  ...             0.0               NaN
# 1113   1114         a  ...             0.0               NaN
# 1114   1115         d  ...          2012.0  Mar,Jun,Sept,Dec
#
# [354 rows x 10 columns]

# %%
store_data.CompetitionOpenSinceYear.fillna(0,inplace=True)
store_data.head()
# Out:
#    Store StoreType  ... Promo2SinceYear    PromoInterval
# 0      1         c  ...             0.0              NaN
# 1      2         a  ...          2010.0  Jan,Apr,Jul,Oct
# 2      3         a  ...          2011.0  Jan,Apr,Jul,Oct
# 3      4         c  ...             0.0              NaN
# 4      5         a  ...             0.0              NaN
#
# [5 rows x 10 columns]

# %%
store_data[store_data.Promo2==0]
# Out:
#       Store StoreType  ... Promo2SinceYear  PromoInterval
# 0         1         c  ...             0.0            NaN
# 3         4         c  ...             0.0            NaN
# 4         5         a  ...             0.0            NaN
# 5         6         a  ...             0.0            NaN
# 6         7         a  ...             0.0            NaN
# ...     ...       ...  ...             ...            ...
# 1107   1108         a  ...             0.0            NaN
# 1109   1110         c  ...             0.0            NaN
# 1111   1112         c  ...             0.0            NaN
# 1112   1113         a  ...             0.0            NaN
# 1113   1114         a  ...             0.0            NaN
#
# [544 rows x 10 columns]

# %%
store_data.Promo2.fillna(0,inplace=True)
store_data.head()
# Out:
#    Store StoreType  ... Promo2SinceYear    PromoInterval
# 0      1         c  ...             0.0              NaN
# 1      2         a  ...          2010.0  Jan,Apr,Jul,Oct
# 2      3         a  ...          2011.0  Jan,Apr,Jul,Oct
# 3      4         c  ...             0.0              NaN
# 4      5         a  ...             0.0              NaN
#
# [5 rows x 10 columns]

# %%
store_data.PromoInterval.fillna(0,inplace=True)
store_data.head()
# Out:
#    Store StoreType  ... Promo2SinceYear    PromoInterval
# 0      1         c  ...             0.0                0
# 1      2         a  ...          2010.0  Jan,Apr,Jul,Oct
# 2      3         a  ...          2011.0  Jan,Apr,Jul,Oct
# 3      4         c  ...             0.0                0
# 4      5         a  ...             0.0                0
#
# [5 rows x 10 columns]

# %%
 column_values = store_data[['CompetitionOpenSinceMonth','CompetitionOpenSinceYear','Promo2SinceWeek','Promo2SinceYear','PromoInterval']].values.ravel()
 unique_values =  pd.unique(column_values)

# %%
unique_values
# Out:
# array([9.0, 2008.0, 0.0, 11.0, 2007.0, 13.0, 2010.0, 'Jan,Apr,Jul,Oct',
#        12.0, 2006.0, 14.0, 2011.0, 2009.0, 4.0, 2015.0, 2013.0, 10.0,
#        2014.0, 8.0, 2000.0, 1.0, 2012.0, 45.0, 'Feb,May,Aug,Nov', 3.0,
#        40.0, 2005.0, 26.0, 6.0, 22.0, 'Mar,Jun,Sept,Dec', 5.0, 1999.0,
#        2003.0, 2.0, 7.0, 31.0, 37.0, 39.0, 2004.0, 27.0, 18.0, 35.0, 23.0,
#        48.0, 36.0, 2002.0, 1961.0, 1995.0, 2001.0, 1990.0, 50.0, 1994.0,
#        44.0, 1900.0, 49.0, 28.0, 1998.0], dtype=object)

# %%
rossman_store.head()
# Out:
#    Store  DayOfWeek        Date  Sales  ...  Open  Promo  StateHoliday SchoolHoliday
# 0      1          5  2015-07-31   5263  ...     1      1             0             1
# 1      2          5  2015-07-31   6064  ...     1      1             0             1
# 2      3          5  2015-07-31   8314  ...     1      1             0             1
# 3      4          5  2015-07-31  13995  ...     1      1             0             1
# 4      5          5  2015-07-31   4822  ...     1      1             0             1
#
# [5 rows x 9 columns]

# %%
rossman_store.tail()
# Out:
#          Store  DayOfWeek        Date  ...  Promo  StateHoliday  SchoolHoliday
# 1017204   1111          2  2013-01-01  ...      0             a              1
# 1017205   1112          2  2013-01-01  ...      0             a              1
# 1017206   1113          2  2013-01-01  ...      0             a              1
# 1017207   1114          2  2013-01-01  ...      0             a              1
# 1017208   1115          2  2013-01-01  ...      0             a              1
#
# [5 rows x 9 columns]

# %%
rossman_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  object
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB

# %% [markdown]
# promo and open are independent variables.

# %%
rossman_store.hist(figsize=(20,20),color='#2E3192')
plt.show()

# %%
rossman_data = pd.merge(store_data,rossman_store,how='inner',on='Store')
rossman_data.head()
# Out:
#    Store StoreType Assortment  ...  Promo  StateHoliday  SchoolHoliday
# 0      1         c          a  ...      1             0              1
# 1      1         c          a  ...      1             0              1
# 2      1         c          a  ...      1             0              1
# 3      1         c          a  ...      1             0              1
# 4      1         c          a  ...      1             0              1
#
# [5 rows x 18 columns]

# %%
rossman_data['Sales'].describe()
# Out:
# count    1.017209e+06
# mean     5.773819e+03
# std      3.849926e+03
# min      0.000000e+00
# 25%      3.727000e+03
# 50%      5.744000e+03
# 75%      7.856000e+03
# max      4.155100e+04
# Name: Sales, dtype: float64

# %%
rossman_data['Day']=pd.DatetimeIndex(rossman_data.Date).day
rossman_data['Month']=pd.DatetimeIndex(rossman_data.Date).month
rossman_data['Year']=pd.DatetimeIndex(rossman_data.Date).year

# %%
rossman_data.head()
# Out:
#    Store StoreType Assortment  ...  Day  Month  Year
# 0      1         c          a  ...   31      7  2015
# 1      1         c          a  ...   30      7  2015
# 2      1         c          a  ...   29      7  2015
# 3      1         c          a  ...   28      7  2015
# 4      1         c          a  ...   27      7  2015
#
# [5 rows x 21 columns]

# %%
sns.set_theme(style='whitegrid',palette='muted')
rossman_data.groupby('Month')[['Customers']].mean().plot(figsize=(10,5),marker='o',color='#2E3192')
plt.grid(False)
plt.show()

# %%
sns.set_theme(style='whitegrid',palette='muted')
rossman_data.groupby('Day')[['Sales']].mean().plot(figsize=(10,5),marker='o',color='#2E3192')
plt.grid(False)
plt.show()

# %%
sns.set_theme(style='whitegrid',palette='muted')
rossman_data.groupby('Month')[['Sales']].mean().plot(figsize=(10,5),marker='o',color='#2E3192')
plt.grid(False)
plt.show()

# %%
sns.set(style="ticks", color_codes=True, font_scale=1.5)

fig, ax1 = plt.subplots(1, figsize=(18, 10))
corr = rossman_data.corr()
sns.heatmap(corr, cmap=sns.diverging_palette(220, 10, as_cmap=True), annot=True, fmt=".2f")
sns.set(font_scale=1.5)

# %%
plt.hist(rossman_data['Sales'])
# Out:
# (array([2.96673e+05, 5.05472e+05, 1.69792e+05, 3.32340e+04, 8.90100e+03,
#         2.36200e+03, 5.65000e+02, 1.74000e+02, 2.80000e+01, 8.00000e+00]),
#  array([    0. ,  4155.1,  8310.2, 12465.3, 16620.4, 20775.5, 24930.6,
#         29085.7, 33240.8, 37395.9, 41551. ]),
#  <a list of 10 Patch objects>)
